# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img = cv2.imread('DATA/00-puppy.jpg')
default_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(default_img)

# %%
default_img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
plt.imshow(default_img)

# %%
default_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(default_img)
